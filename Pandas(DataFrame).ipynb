# %% [markdown]
# <a href="https://colab.research.google.com/github/KulsoomBibi/DataScienceWithAtomCamp/blob/main/Pandas(DataFrame).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **The most important data structure of pandasis the DataFrame. Its a tabular structure tightly integrated with Series**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# DataFrame looks like a table

# %%
df = pd.DataFrame({
    'Population' :[35.467, 63.951, 80.94, 60.665, 127.061
                   ],
                   'GDP' : [1785387, 2874437, 2167744, 4602367, 2950039
                            ],
                   'Surface Area' : [9984670, 640679, 357114, 242495, 9525067
                                     ],
                   'HDI' : [0.913, 0.888, 0.874, 0.364, 0.915
                          ],
                   'Continent': ['America','Europe', 'Europe', 'Asia', 'America'
                   ]
    }, columns=['Population','GDP',  'Surface Area','HDI',  'Continent'])

# %%
df
# Out:
#    Population      GDP  Surface Area    HDI Continent
# 0      35.467  1785387       9984670  0.913   America
# 1      63.951  2874437        640679  0.888    Europe
# 2      80.940  2167744        357114  0.874    Europe
# 3      60.665  4602367        242495  0.364      Asia
# 4     127.061  2950039       9525067  0.915   America

# %%
df.index = ['Canada',
            'France',
            'Germany',
            'Japan',
            'United Kingdom']

# %%
df
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# Canada              35.467  1785387       9984670  0.913   America
# France              63.951  2874437        640679  0.888    Europe
# Germany             80.940  2167744        357114  0.874    Europe
# Japan               60.665  4602367        242495  0.364      Asia
# United Kingdom     127.061  2950039       9525067  0.915   America

# %%
df.shape # rows=Obervation, columns= features
# Out:
# (5, 5)

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Japan', 'United Kingdom'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Canada to United Kingdom
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    5 non-null      float64
#  1   GDP           5 non-null      int64
#  2   Surface Area  5 non-null      int64
#  3   HDI           5 non-null      float64
#  4   Continent     5 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 412.0+ bytes

# %%
df.size
# Out:
# 25

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    5.000000  5.000000e+00  5.000000e+00  5.000000
# mean    73.616800  2.875995e+06  4.150005e+06  0.790800
# std     34.009175  1.081306e+06  5.121148e+06  0.239211
# min     35.467000  1.785387e+06  2.424950e+05  0.364000
# 25%     60.665000  2.167744e+06  3.571140e+05  0.874000
# 50%     63.951000  2.874437e+06  6.406790e+05  0.888000
# 75%     80.940000  2.950039e+06  9.525067e+06  0.913000
# max    127.061000  4.602367e+06  9.984670e+06  0.915000

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# Name: count, dtype: int64

# %% [markdown]
# **Indexing, Selection and Slicing**

# %%
df
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# Canada              35.467  1785387       9984670  0.913   America
# France              63.951  2874437        640679  0.888    Europe
# Germany             80.940  2167744        357114  0.874    Europe
# Japan               60.665  4602367        242495  0.364      Asia
# United Kingdom     127.061  2950039       9525067  0.915   America

# %%
df['Canada']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Canada'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-287040cfbb3b> in <cell line: 1>()
# ----> 1 df['Canada']
#
# ...

# %%
df['Population'] #column
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Japan              60.665
# United Kingdom    127.061
# Name: Population, dtype: float64

# %% [markdown]
# Loc and Iloc is used when you want to access a certain rows(Obervaction) , Iloc is for indexing(0,1,3,)

# %%
df.loc['Canada'] # certain row
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[-5]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.log[-5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-1f275d0001a0> in <cell line: 1>()
# ----> 1 df.log[-5]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'log'

# %% [markdown]
# Multiple columns also selectd similary numpy and series

# %%
df[["Population", "GDP"]]
# Out:
#                 Population      GDP
# Canada              35.467  1785387
# France              63.951  2874437
# Germany             80.940  2167744
# Japan               60.665  4602367
# United Kingdom     127.061  2950039

# %%
Slicing

# %%
#df[Row starting, row ending, columns starting, columns ending]

# %%
df[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2874437        640679  0.888    Europe
# Germany      80.940  2167744        357114  0.874    Europe

# %%
df.loc['France': 'Japan']
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2874437        640679  0.888    Europe
# Germany      80.940  2167744        357114  0.874    Europe
# Japan        60.665  4602367        242495  0.364      Asia

# %%
df.loc['France': 'Japan', ['Population']]
# Out:
#          Population
# France       63.951
# Germany      80.940
# Japan        60.665

# %%
df.iloc[1:3, [0,3]]
# Out:
#          Population    HDI
# France       63.951  0.888
# Germany      80.940  0.874
